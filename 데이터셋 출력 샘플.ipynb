# %%
import dataset
import PIL

c_data_set= dataset.custom_dataset("./dict/data/sample.txt","./font","train")

# %%
for i in range(0,len(c_data_set)):
    img,text = c_data_set.__getitem__(i)
    display(img)
# Out:
# <PIL.Image.Image image mode=L size=141x47 at 0x7FC92B598290>
# <PIL.Image.Image image mode=L size=310x47 at 0x7FCA95915910>
# <PIL.Image.Image image mode=L size=310x47 at 0x7FC92E4BC850>
# <PIL.Image.Image image mode=L size=451x47 at 0x7FC92B598590>
# <PIL.Image.Image image mode=L size=78x47 at 0x7FC92E4BCB90>
# <PIL.Image.Image image mode=L size=205x51 at 0x7FC92B598650>
# <PIL.Image.Image image mode=L size=207x56 at 0x7FC92E4BCC50>
# <PIL.Image.Image image mode=L size=299x50 at 0x7FC92E4BCE10>
