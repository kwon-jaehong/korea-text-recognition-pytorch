# %%
import dataset
import PIL

c_data_set= dataset.custom_dataset("./dict/dict.txt","./font")

# %%
for i in range(0,len(c_data_set)):
    img,text = c_data_set.__getitem__(i)
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=374x51 at 0x7F88E1C8D7D0>
# <PIL.Image.Image image mode=RGB size=449x56 at 0x7F87AA08BF50>
# <PIL.Image.Image image mode=RGB size=431x67 at 0x7F88E0220E90>
# <PIL.Image.Image image mode=RGB size=473x81 at 0x7F87AA1097D0>
# <PIL.Image.Image image mode=RGB size=293x67 at 0x7F88E1CA8AD0>
# <PIL.Image.Image image mode=RGB size=394x67 at 0x7F87AA08BF50>
# <PIL.Image.Image image mode=RGB size=424x82 at 0x7F88E1CA8AD0>
# <PIL.Image.Image image mode=RGB size=420x66 at 0x7F87B0B7F610>
# <PIL.Image.Image image mode=RGB size=360x65 at 0x7F88E7370B10>
# <PIL.Image.Image image mode=RGB size=435x70 at 0x7F87AA109CD0>
# <PIL.Image.Image image mode=RGB size=459x67 at 0x7F87B0B7F610>
# <PIL.Image.Image image mode=RGB size=487x65 at 0x7F87AA109CD0>

# %%
import pandas as pd
ddf = pd.read_csv("./dict/nia_사전.csv",encoding="cp949")
ddf
# Out:
#                  가
# 0               가뇨
# 1               가니
# 2              가니오
# 3              가니와
# 4               가라
# ...            ...
# 929129  1234567890
# 929130  1234567890
# 929131  1234567890
# 929132  1234567890
# 929133  1234567890
#
# [929134 rows x 1 columns]
